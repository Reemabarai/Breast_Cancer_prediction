# %%
import pandas as pd
import numpy as np

# %%
breast = pd.read_csv('data.csv')
breast.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
breast.shape
# Out:
# (569, 33)

# %%
breast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
breast.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#MISSING VALUE
print("\n Missing value :")
breast.isnull().sum()
# Out:
#  Missing value :
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# ...

# %%
breast.drop(['Unnamed: 32'], axis=1, inplace=True, errors='ignore')

# %%
breast.shape
# Out:
# (569, 32)

# %%
#HANDLING DULICATION
duplicated_raws = breast.duplicated().sum()
print(f"Number of duplicated raws:",duplicated_raws)
# Out:
# Number of duplicated raws: 0

# %%
breast['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
#ENCODING CATEGORICAL DATA
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
breast['diagnosis'] = le.fit_transform(breast['diagnosis'])
print("categorical data encoded succefully")
breast.head()
# Out:
# categorical data encoded succefully
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
breast['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
#FEATURE SCALING
from sklearn.preprocessing import StandardScaler

feature = breast.drop('diagnosis',axis=1)
target=breast['diagnosis']
sc = StandardScaler()
scaled_features = sc.fit_transform(feature)
print("Feature scaling complete")
# Out:
# Feature scaling complete

# %%
x = breast.drop('diagnosis',axis=1)
y = breast['diagnosis']

# %%
x.shape
# Out:
# (569, 31)

# %%
# Apply StandardScaler
scaler = StandardScaler()
scaled_features = scaler.fit_transform(feature)
# Convert back to DataFrame
breast_scaled = pd.DataFrame(scaled_features, columns=feature.columns)
print(breast_scaled.head())
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0 -0.236405     1.097064     -2.073335        1.269934   0.984375
# 1 -0.236403     1.829821     -0.353632        1.685955   1.908708
# 2  0.431741     1.579888      0.456187        1.566503   1.558884
# 3  0.432121    -0.768909      0.253732       -0.592687  -0.764464
# 4  0.432201     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#splitting data into traning and testing sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
sc.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train.shape
# Out:
# (455, 31)

# %%
x_test.shape
# Out:
# (114, 31)

# %%
x_train
# Out:
# array([[-0.23626772, -1.44798723, -0.45602336, ...,  0.91959172,
#          2.14719008,  1.85943247],
#        [-0.23615466,  1.97750799,  1.69418666, ...,  2.6752184 ,
#          1.9368786 ,  2.46346488],
#        [-0.23626992, -1.40708919, -1.26351565, ..., -0.97048581,
#          0.61676962,  0.05287682],
#        ...,
#        [-0.17181166,  0.04621146, -0.57470379, ..., -1.23756033,
#         -0.71628161, -1.26047806],
#        [-0.23587529, -0.04183295,  0.07687501, ...,  1.03683652,
#          0.45013821,  1.19444266],
#        [-0.23623974, -0.5530585 ,  0.28631105, ..., -0.61357437,
#         -0.33448538, -0.84042616]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
sns.heatmap(breast.iloc[:,1:10].corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf_model = RandomForestClassifier()
rf_model.fit(x_train, y_train)
rf_pred = rf_model.predict(x_test)

rf_acc = accuracy_score(y_test, rf_pred)
print("Random Forest Accuracy:", rf_acc)
# Out:
# Random Forest Accuracy: 0.9649122807017544

# %%
from sklearn.svm import SVC
svc_classifier = SVC()
svc_classifier.fit(x_train, y_train)
y_pred_svc = svc_classifier.predict(x_test)
svm_acc = accuracy_score(y_test, y_pred_svc)
print("SVM Accuracy (Linear Kernel):", svm_acc)
# Out:
# SVM Accuracy (Linear Kernel): 0.9824561403508771

# %%
from sklearn.metrics import classification_report

# Random Forest Report
print("Random Forest Classification Report:")
print(classification_report(y_test, rf_pred))

# SVM Report
print("SVM Classification Report:")
print(classification_report(y_test, y_pred_svc))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        71
#            1       0.98      0.93      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        71
#            1       1.00      0.95      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# Calculate accuracy
rf_acc = accuracy_score(y_test, rf_pred)
svm_acc = accuracy_score(y_test, y_pred_svc)

# Plot
plt.bar(['Random Forest', 'SVM'], [rf_acc, svm_acc], color=['skyblue', 'salmon'])
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')
plt.ylim(0, 1)
plt.grid(axis='y')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Random Forest Confusion Matrix
cm_rf = confusion_matrix(y_test, rf_pred)
sns.heatmap(cm_rf, annot=True, fmt='d')
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Random Forest Confusion Matrix
cm_rf = confusion_matrix(y_test, y_pred_svc)
sns.heatmap(cm_rf, annot=True, fmt='d')
plt.title("SVM Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
input_text = (-0.2363115 ,  1.46060215,  1.67091599,  1.48000371,  1.44227543,
       -0.1672588 ,  1.2803433 ,  0.96548587,  0.69671749,  0.15108104,
       -0.02659565,  0.54364788, -1.10793532,  0.32768095,  0.61237184,
       -0.67535369,  0.43045347,  0.10200041, -0.34925965, -0.61898948,
        0.03823975,  1.63197811,  0.85049678,  1.61256917,  1.63910747,
        0.8123407 ,  2.5746798 ,  1.61634093,  0.97288481,  1.24770406,
        1.57127022)
np_df = np.asarray(input_text)
prediciont = rf_model.predict(np_df.reshape(1,-1))
if prediciont[0] == 1:
     print("Cancerous")
else:
     print("Not cancerous")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       1 input_text = (-0.2363115 ,  1.46060215,  1.67091599,  1.48000371,  1.44227543,
#       2        -0.1672588 ,  1.2803433 ,  0.96548587,  0.69671749,  0.15108104,
#       3        -0.02659565,  0.54364788, -1.10793532,  0.32768095,  0.61237184,
#    (...)
#       6         0.8123407 ,  2.5746798 ,  1.61634093,  0.97288481,  1.24770406,
#       7         1.57127022)
# ----> 8 np_df = np.asarray(input_text)
#       9 prediciont = rf_model.predict(np_df.reshape(1,-1))
#      10 if prediciont[0] == 1:
#
# NameError: name 'np' is not defined

# %%
x_train[25]
# Out:
# array([-0.23612338,  0.09165373,  0.21649904,  0.10383912, -0.03466706,
#         0.16793043,  0.3081324 ,  0.36661375,  0.28066056,  0.50522255,
#         0.26401318, -0.70730431, -1.02683415, -0.70297279, -0.4602115 ,
#        -0.99903348, -0.5314055 , -0.39436023, -0.72883026, -0.64441597,
#        -0.68800283,  0.42675779,  0.72347862,  0.3168852 ,  0.2872726 ,
#         1.00083503,  0.96270176,  1.07709928,  1.05358578,  2.9965249 ,
#         0.96169623])

# %%
x_train[10]
# Out:
# array([-0.2362507 , -0.50193594,  0.58417564, -0.50206873, -0.53693558,
#        -0.61488943, -0.18744878, -0.35969133, -0.29583495,  0.43220368,
#         0.17612173, -0.3875283 ,  0.51735394, -0.32823461, -0.42654888,
#         0.02367466, -0.03063523, -0.16126635,  0.18392352, -0.1165137 ,
#         0.25270826, -0.5051136 ,  0.78535926, -0.47065237, -0.53771584,
#        -0.08629507, -0.05066881, -0.13811343,  0.08974217,  0.11525763,
#         0.48013277])

# %%
x_train[15]
# Out:
# array([-0.2363115 ,  1.46060215,  1.67091599,  1.48000371,  1.44227543,
#        -0.1672588 ,  1.2803433 ,  0.96548587,  0.69671749,  0.15108104,
#        -0.02659565,  0.54364788, -1.10793532,  0.32768095,  0.61237184,
#        -0.67535369,  0.43045347,  0.10200041, -0.34925965, -0.61898948,
#         0.03823975,  1.63197811,  0.85049678,  1.61256917,  1.63910747,
#         0.8123407 ,  2.5746798 ,  1.61634093,  0.97288481,  1.24770406,
#         1.57127022])

# %%
import pickle
pickle.dump(rf_model,open('model.pkl','wb'))

# %%
pickle.dump(scaled_features,open('scaler.pkl','wb'))
